# %% [markdown]
# <a href="https://colab.research.google.com/github/TaqwaAhmad-w/Prediction-of-Product-Sales/blob/main/Prediction_of_Product_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Title: Prediction of Product Sales
#  -Author: Taqwa Ahmad
#  ## Project Overview
#  ## Load and Inspect Data
#  ## Clean Data
#  ## Exploratory Data Analysis
#  ## Feature Inspection
#
# `

# %%
import pandas as pd

fpath='/content/drive/MyDrive/AXSOSACADEMY/01-Fundamentals/Week02/Data/sales_predictions_2023.csv'
df=pd.read_csv(fpath)
df.info()
df.head()
for i in df.columns:
  print(f'values in {i} coulmn:')
  print(df[i].value_counts())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB
# ...

# %%
df.duplicated().sum()
df.isna().sum()
cat_cols=df.select_dtypes('object').columns
df[cat_cols]=df[cat_cols].fillna('MISSING')
num_cols=df.select_dtypes('number').columns
df[num_cols]=df[num_cols].fillna(-1)
df.isna().sum()
print(cat_cols)
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
for col in cat_cols:
  print(f'{col} ')
  print(df[col].nunique())
  print(df[col].value_counts())
  print()


#Low Fat    5089
#Regular    2889
#LF          316
#reg         117
#low fat
# Out:
# Item_Identifier
# 1559
# Item_Identifier
# FDW13    10
# FDG33    10
# FDX31     9
# FDT07     9
# NCY18     9
#          ..
# FDO33     1
# FDK57     1
# FDT35     1
# FDN52     1
# FDE52     1
# Name: count, Length: 1559, dtype: int64
#
# Item_Fat_Content
# 5
# Item_Fat_Content
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: count, dtype: int64
#
# Item_Type
# 16
# Item_Type
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: count, dtype: int64
#
# Outlet_Identifier
# 10
# ...

# %%
replace_dict={'LF':'Low Fat','reg':'Regular','low fat':'Low Fat'}
df['Item_Fat_Content']=df['Item_Fat_Content'].replace(replace_dict)
df['Item_Fat_Content'].value_counts()
# Out:
# Item_Fat_Content
# Low Fat    5517
# Regular    3006
# Name: count, dtype: int64

# %%
for col in num_cols:
  print(f'{col} ')
  print(df[col].nunique())
  print(df[col].value_counts())
  print()
# Out:
# Item_Weight
# 416
# Item_Weight
# -1.000     1463
#  12.150      86
#  17.600      82
#  13.650      77
#  11.800      76
#            ...
#  5.210        2
#  9.420        1
#  7.685        1
#  5.400        1
#  6.520        1
# Name: count, Length: 416, dtype: int64
#
# Item_Visibility
# 7880
# Item_Visibility
# 0.000000    526
# 0.076975      3
# 0.061271      2
# 0.046825      2
# 0.112399      2
#            ...
# 0.054142      1
# 0.018920      1
# 0.044974      1
# 0.103611      1
# 0.083060      1
# Name: count, Length: 7880, dtype: int64
#
# Item_MRP
# 5938
# Item_MRP
# 172.0422    7
# 170.5422    6
# 142.0154    6
# 109.5228    6
# 188.1872    6
#            ..
# 108.7912    1
# 157.5972    1
# 245.2118    1
# 232.3326    1
# 39.6164     1
# Name: count, Length: 5938, dtype: int64
#
# Outlet_Establishment_Year
# 9
# Outlet_Establishment_Year
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# ...

# %%
for col in num_cols:
  print(f'the min of {col} ')
  print(df[col].min())
  print(f'the max of {col} ')
  print(df[col].max())
  print(f'the mean of {col} ')
  print(df[col].mean())

  #print(df[col].value_counts())
  print()
# Out:
# the min of Item_Weight
# -1.0
# the max of Item_Weight
# 21.35
# the mean of Item_Weight
# 10.478936407368296
#
# the min of Item_Visibility
# 0.0
# the max of Item_Visibility
# 0.328390948
# the mean of Item_Visibility
# 0.06613202877895108
#
# the min of Item_MRP
# 31.29
# the max of Item_MRP
# 266.8884
# the mean of Item_MRP
# 140.9927819781767
#
# the min of Outlet_Establishment_Year
# 1985
# the max of Outlet_Establishment_Year
# 2009
# the mean of Outlet_Establishment_Year
# 1997.8318667135984
#
# the min of Item_Outlet_Sales
# 33.29
# the max of Item_Outlet_Sales
# 13086.9648
# the mean of Item_Outlet_Sales
# 2181.288913575032
